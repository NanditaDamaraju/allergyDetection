# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from preprocessUtils import *
from dataUtils import *
from augmentationUtils import *
from modelUtils import *

# %% [markdown]
# # Load test data

# %%
test_imgs = load_data_from_folder_into_matrix('data/testing_patches/')
# Out:
# 0 out of 452 images processed
# 100 out of 452 images processed
# 200 out of 452 images processed
# 300 out of 452 images processed
# 400 out of 452 images processed

# %% [markdown]
# # Load Model and Weights

# %%
custom_model = create_custom_model()
custom_model.load_weights('data/model.h5')
# Out:
# WARNING:tensorflow:From /Users/nandita.damaraju/Library/Python/3.7/lib/python/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# # Generate Predictions

# %%
#swap axes to match input to model
test_imgs = np.swapaxes(test_imgs, 3,0)
test_imgs = np.swapaxes(test_imgs, 2,3)
test_imgs.shape
# Out:
# (452, 100, 100, 3)

# %%
pred_probs = custom_model.predict(temp)

# %% [markdown]
# # Test prediction analysis

# %%
#get all positive predictions
positive_threshold = 0.95
predicted_positive = np.where(pred_probs[:,1] > positive_threshold)
plt.figure(figsize = (20,12))
for i,idx in enumerate(predicted_positive[0]):
    plt.subplot(len(predicted_positive[0])/2,3, i+1)
    plt.imshow(test_imgs[idx])
